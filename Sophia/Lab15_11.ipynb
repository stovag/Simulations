# %%
# import libraries
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
size_of_array_x = 20
size_of_array_y = 20
full_size = 20*20
# informed_nodes = 0
current_informed = 0
initial_array = [[0 for i in range(size_of_array_x)] for j in range(size_of_array_y)]

informed_nodes = []

# %%
x = random.randint(0,19)
y = random.randint(0,19)
print(x,y)
initial_array[x][y] = 1
# informed_nodes += 1
current_informed += 1

print(initial_array)

# %%
print(full_size)
while current_informed < full_size:
  x = random.randint(0,19)
  y = random.randint(0,19)

  if initial_array[x][y] == 0:
    initial_array[x][y] = 1
    current_informed += 1
  informed_nodes.append(current_informed)
  print(len(informed_nodes))

# %%
plt.plot(informed_nodes)
plt.title("Infected per Step")
plt.show()

# %%
# with success rate

# %%
# import libraries
# possibility 30%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
size_of_array_x = 20
size_of_array_y = 20
full_size = 20*20
# informed_nodes = 0
current_informed_30 = 0
initial_array_30 = [[0 for i in range(size_of_array_x)] for j in range(size_of_array_y)]

informed_nodes_30 = []

# %%
x = random.randint(0,19)
y = random.randint(0,19)
print(x,y)
initial_array[x][y] = 1
# informed_nodes += 1
current_informed_30 += 1

print(initial_array_30)
# Out:
# 15 10
# ...

# %%
print(full_size)
while current_informed_30 < full_size:
  possibility = random.randint(1,10)
  print("Possibility",possibility)
  x = random.randint(0,19)
  y = random.randint(0,19)

  if initial_array_30[x][y] == 0:
    if possibility <= 3:
      initial_array_30[x][y] = 1
      current_informed_30 += 1
  informed_nodes.append(current_informed_30)
  print(len(informed_nodes_30))

# %%
plt.plot(informed_nodes_30)
plt.title("Infected per Step")
plt.show()

# %%
# import libraries
# possibility 50%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
size_of_array_x = 20
size_of_array_y = 20
full_size = 20*20
# informed_nodes = 0
current_informed_50 = 0
initial_array_50 = [[0 for i in range(size_of_array_x)] for j in range(size_of_array_y)]

informed_nodes_50 = []

# %%
x = random.randint(0,19)
y = random.randint(0,19)
print(x,y)
initial_array[x][y] = 1
# informed_nodes += 1
current_informed_50 += 1

print(initial_array_50)
# Out:
# 9 12
# ...

# %%
print(full_size)

while current_informed_50 < full_size:
  possibility = random.randint(1,10)
  x = random.randint(0,19)
  y = random.randint(0,19)

  if initial_array_50[x][y] == 0:
    if possibility <= 3:
      initial_array_50[x][y] = 1
      current_informed_50 += 1
  informed_nodes.append(current_informed_50)
  print(len(informed_nodes_50))

# %%
plt.plot(informed_nodes_50)
plt.title("Infected per Step")
plt.show()

# %%
# import libraries
# possibility 30%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
size_of_array_x = 20
size_of_array_y = 20
full_size = 20*20
# informed_nodes = 0
current_informed_80 = 0
initial_array_80 = [[0 for i in range(size_of_array_x)] for j in range(size_of_array_y)]

informed_nodes_80 = []

# %%
x = random.randint(0,19)
y = random.randint(0,19)
print(x,y)
initial_array[x][y] = 1
# informed_nodes += 1
current_informed_80 += 1

print(initial_array_80)

# %%
print(full_size)
possibility = random.randint(1,10)
while current_informed_80 < full_size:
  x = random.randint(0,19)
  y = random.randint(0,19)

  if initial_array_80[x][y] == 0:
    if possibility <= 3:
      initial_array_80[x][y] = 1
      current_informed_80 += 1
  informed_nodes.append(current_informed_80)
  print(len(informed_nodes_80))

# %%
plt.plot(informed_nodes_80)
plt.title("Infected per Step")
plt.show()
