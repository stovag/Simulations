# %% [markdown]
# <h2>Εξάπλωση ιού σε δίκτυο</h2>
# Έστω δίκτυο με Ν=1000 κόμβοι.
# 0 = healthy
# 1 = infected

# %%
import numpy as np
import random as r
from matplotlib import pyplot as plt

nodes = np.zeros(n)
nodes[r.randint(1, n-1)] = 1
infected = 1
l = []

while infected < n:
    for i in range(infected):
        target = r.randint(0, n-1)
        if nodes[target] == 0:
            nodes[target] = 1
            infected += 1
    l.append(infected)

d = [l[i]-l[i-1] for i in range(1, len(l))]
print("Steps:", len(d))    
    
plt.plot(l)
plt.title("Infected per Step")
plt.show()

plt.plot(d)
plt.title("Infection Rate per Step")
plt.show()
# Out:
# Steps: 21
